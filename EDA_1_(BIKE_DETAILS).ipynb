# %% [markdown]
# ***EDA > EDA 1 >> BIKE DETAILS***

# %% [markdown]
# 1 . What is the range of selling prices in the dataset ?

# %% [markdown]
# Minimum Selling Price: ₹5,000
#
# Maximum Selling Price: ₹7,60,000
#
# Range = ₹7,60,000 − ₹5,000 = ₹7,55,000

# %% [markdown]
# 2 . What is the median selling price for bikes in the dataset ?

# %% [markdown]
# Median Selling Price: ₹45,000

# %% [markdown]
# 3 . What is the most common seller type ?

# %% [markdown]
# Most common seller type is: Individual

# %% [markdown]
# 4 . How many bikes have driven more than 50,000 kilometers ?

# %% [markdown]
# Total 170 bikes

# %% [markdown]
#  5 . What is the average km_driven value for each ownership type ?

# %% [markdown]
# 1st owner: 32,816.58 km
#
# 2nd owner: 39,288.99 km
#
# 3rd owner: 33,292.18 km
#
# 4th owner: 3,11,500.00 km

# %% [markdown]
# 6 . What proportion of bikes are from the year 2015 or older ?

# %% [markdown]
# The proportion of bikes that are from 2015 or older is 56.64%

# %% [markdown]
# 7 . What is the trend of missing values across the dataset ?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8 . What is the highest ex_showroom_price recorded, and for which bike ?

# %% [markdown]
# Harley-Davidson Street Bob — ₹12,78,000

# %% [markdown]
# 9 . What is the total number of bikes listed by each seller type ?

# %% [markdown]
# Individual: 1055 bikes
#
# Dealer: 6 bikes

# %% [markdown]
# 10 . What is the relationship between selling_price and km_driven for first-owner bikes ?

# %% [markdown]
# ![output.png](data:image/png;base64,...)

# %% [markdown]
# 11 .  Identify and remove outliers in the km_driven column using the IQR method ?

# %% [markdown]
# Total 39 outliers remove then 1022 rows remaining .

# %% [markdown]
# 12 . Perform a bivariate analysis to visualize the relationship between year and selling_price ?

# %% [markdown]
# ![output (1).png](data:image/png;base64,...)

# %% [markdown]
# 13 . What is the average depreciation in selling price based on the bike's age (current year - manufacturing
# year) ?

# %% [markdown]
# ![output (2).png](data:image/png;base64,...)

# %% [markdown]
# 14 . Which bike names are priced significantly above the average price for their manufacturing year ?

# %% [markdown]
# Priced significantly (50%+) higher than the average price of its manufacturing year

# %% [markdown]
# 15 .  Develop a correlation matrix for numeric columns and visualize it using a heatmap ?

# %% [markdown]
# ![output (3).png](data:image/png;base64,...)
